# %%
"""
TESTS SYNERGIE GEOGRID / GEOIM - PARTIE 2
recalage de rasters de résolution différente
"""

# %%
# # Fabrication des inputs : Raster A et B de même emprise, une seule bande, de résolutions différentes
# import raster_tools as rt
# base_path = r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\05-20090805-0965-6445-LA93-0M50-C070.tif"
# sub_area_path = r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\sub_area.shp"
# 
# # Ouverture du raster de base
# base = rt.openGeoRaster(base_path, roi=sub_area_path)
# 
# # Extraction d'une seule bande
# b1 = rt.GeoIm(base.pxData[0], base.geogrid)
# b1.exportAsRasterFile(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\base.tif")

# %%
# # resampler le raster basique pour en avoir 2 à des résolutions différentes
# import raster_tools as rt
# A1 = rt.openGeoRaster(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\base.tif", res=1)
# 
# # Ligne noire qui nous embête
# A1_1 = rt.GeoIm(A1.pxData[0:A1.geogrid.nRows, 0:A1.geogrid.nCols-1], rt.GeoGrid(A1.geogrid.xMin, A1.geogrid.yMax, A1.geogrid.xRes, A1.geogrid.yRes, A1.geogrid.nCols-1, A1.geogrid.nRows, A1.geogrid.crs))
# A1_1.exportAsRasterFile(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\A1_1.tif")
# Out:
# base.tif loaded
#
# A1_1.tif OK

# %%
# resampler le raster basique pour en avoir 2 à des résolutions différentes
# import raster_tools as rt
# A3 = rt.openGeoRaster(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\base.tif", res=3)
# 
# Ligne noire qui nous embête
# A3_1 = rt.GeoIm(A3.pxData[0:A3.geogrid.nRows, 0:A3.geogrid.nCols-1], rt.GeoGrid(A3.geogrid.xMin, A3.geogrid.yMax, A3.geogrid.xRes, A3.geogrid.yRes, A3.geogrid.nCols-1, A3.geogrid.nRows, A3.geogrid.crs))
# A3_1.exportAsRasterFile(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\A3.tif")
# Out:
# base.tif loaded
#
# A3.tif OK

# %%
# Ecriture des geogrids respective pour pouvoir comprendre le décalage
# A1_1.geogrid.writeAllCellsInShapefile(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\A1_grid.shp")
# A3.geogrid.writeAllCellsInShapefile(r"C:\Users\Eudes\Desktop\tests_GeoGrid\partie_2\A3_grid.shp")
# Out:
# C:\Users\Eudes\anaconda3\envs\edgesII\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# C:\Users\Eudes\anaconda3\envs\edgesII\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
A1_1

# %%
A3_1
